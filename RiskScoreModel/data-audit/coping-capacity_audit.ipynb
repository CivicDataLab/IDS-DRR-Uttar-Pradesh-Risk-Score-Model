# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
master_var = pd.read_csv(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\RiskScoreModel\data\MASTER_VARIABLES.csv')

# %%
#bool_series = pd.isnull(master_var)

master_var.shape[0] - master_var.dropna().shape[0]

# filtering data  
# displaying data only with Gender = NaN  
#master_var[bool_series]
# Out:
# 0

# %%
scores = pd.read_csv(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\RiskScoreModel\data\factor_scores_l1_government-response.csv')

# %%
cc_score = scores[['object_id','revenue_ci_y','government-response','SDRF_tenders_awarded_value','total_tender_awarded_value']]

# %%
cop_cap = master_var[['object_id','revenue_ci_y','SDRF_tenders_awarded_value','total_tender_awarded_value']]
cop_cap
# Out:
#       object_id     revenue_ci_y  SDRF_tenders_awarded_value  \
# 0           101  Gossaigaon (Pt)                        0.00
# 1           101  Gossaigaon (Pt)                        0.00
# 2           101  Gossaigaon (Pt)                  9957710.23
# 3           101  Gossaigaon (Pt)                        0.00
# 4           101  Gossaigaon (Pt)                  7991730.00
# ...         ...              ...                         ...
# 5215        281           Majuli                        0.00
# 5216        281           Majuli                        0.00
# 5217        281           Majuli                        0.00
# 5218        281           Majuli                        0.00
# 5219        281           Majuli                        0.00
#
#       total_tender_awarded_value
# 0                           0.00
# 1                    17884047.70
# 2                    23957462.01
# 3                    22246865.21
# 4                     7991730.00
# ...

# %% [markdown]
# ### EDA

# %%
cc_score.hist(bins=30, figsize=(25, 20))
# Out:
# array([[<Axes: title={'center': 'object_id'}>,
#         <Axes: title={'center': 'government-response'}>],
#        [<Axes: title={'center': 'SDRF_tenders_awarded_value'}>,
#         <Axes: title={'center': 'total_tender_awarded_value'}>]],
#       dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

envplot = cc_score.filter([
    'government-response','SDRF_tenders_awarded_value','total_tender_awarded_value',    
],axis=1)
g = sns.pairplot(envplot)
plt.show()

# %%
cop_cap.describe()
# Out:
#          object_id  SDRF_tenders_awarded_value  total_tender_awarded_value
# count  5220.000000                5.220000e+03                5.220000e+03
# mean    190.788889                8.736913e+05                6.931983e+06
# std      52.322312                7.691356e+06                4.017416e+07
# min     101.000000                0.000000e+00                0.000000e+00
# 25%     145.750000                0.000000e+00                0.000000e+00
# 50%     190.500000                0.000000e+00                0.000000e+00
# 75%     236.250000                0.000000e+00                0.000000e+00
# max     281.000000                3.055069e+08                1.018062e+09
