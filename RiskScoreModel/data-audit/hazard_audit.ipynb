# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
haz_score = pd.read_csv(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\RiskScoreModel\data\factor_scores_l1_flood-hazard.csv')

# %%
haz_var = haz_score[["object_id","revenue_ci_y","timeperiod","inundation_intensity_mean_nonzero","inundation_intensity_sum"]]

# %%
haz_var
# Out:
#       object_id     revenue_ci_y timeperiod  \
# 0           101  Gossaigaon (Pt)    2021_04
# 1           101  Gossaigaon (Pt)    2021_05
# 2           101  Gossaigaon (Pt)    2021_06
# 3           101  Gossaigaon (Pt)    2021_07
# 4           101  Gossaigaon (Pt)    2021_08
# ...         ...              ...        ...
# 5215        281           Majuli    2023_04
# 5216        281           Majuli    2023_05
# 5217        281           Majuli    2023_06
# 5218        281           Majuli    2023_07
# 5219        281           Majuli    2023_08
#
#       inundation_intensity_mean_nonzero  inundation_intensity_sum
# 0                              0.000000                       0.0
# 1                              0.000000                       0.0
# 2                              0.000000                       0.0
# 3                              0.000000                       0.0
# 4                              0.500000                    8292.5
# ...

# %%
haz_var.describe()
# Out:
#          object_id  inundation_intensity_mean_nonzero  \
# count  5220.000000                        5220.000000
# mean    190.788889                           0.087097
# std      52.322312                           0.187459
# min     101.000000                           0.000000
# 25%     145.750000                           0.000000
# 50%     190.500000                           0.000000
# 75%     236.250000                           0.000000
# max     281.000000                           1.000000
#
#        inundation_intensity_sum
# count               5220.000000
# mean                7412.175378
# std                27543.891786
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max               441751.000000

# %%
haz_var.hist(bins=30, figsize=(25, 20))
# Out:
# array([[<Axes: title={'center': 'object_id'}>,
#         <Axes: title={'center': 'inundation_intensity_mean_nonzero'}>],
#        [<Axes: title={'center': 'inundation_intensity_sum'}>, <Axes: >]],
#       dtype=object)
