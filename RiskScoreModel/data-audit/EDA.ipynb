# %%
import pandas as pd

# %%
master = pd.read_csv(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\RiskScoreModel\data\MASTER_VARIABLES.csv')

# %%
master
# Out:
#       object_id   district  rc_area timeperiod  total_tender_awarded_value  \
# 0           101  KOKRAJHAR     1069    2021_04                        0.00
# 1           101  KOKRAJHAR     1069    2021_05                 17884047.70
# 2           101  KOKRAJHAR     1069    2021_06                 23957462.01
# 3           101  KOKRAJHAR     1069    2021_07                 22246865.21
# 4           101  KOKRAJHAR     1069    2021_08                  7991730.00
# ...         ...        ...      ...        ...                         ...
# 5215        281     MAJULI      648    2023_04                        0.00
# 5216        281     MAJULI      648    2023_05                        0.00
# 5217        281     MAJULI      648    2023_06                        0.00
# 5218        281     MAJULI      648    2023_07                        0.00
# 5219        281     MAJULI      648    2023_08                        0.00
#
#       SOPD_tenders_awarded_value  SDRF_tenders_awarded_value  \
# ...

# %%
vul_var = master['']
